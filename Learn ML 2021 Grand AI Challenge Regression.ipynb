# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Load the dataset using pandas
df = pd.read_csv("new_train.csv") 
df.head(5)
# Out:
#        Date  Open-Stock-1  High-Stock-1  Low-Stock-1  Close-Stock-1  \
# 0  6/1/2010        1889.7       1890.00      1838.00        1855.10
# 1  6/2/2010        1848.0       1862.75      1828.00        1853.05
# 2  6/3/2010        1864.1       1910.00      1864.10        1905.60
# 3  6/4/2010        1906.0       1909.80      1880.10        1885.70
# 4  6/7/2010        1867.0       1894.85      1808.35        1876.65
#
#    VWAP-Stock-1  Volume-Stock-1  Turnover-Stock-1  Open-Stock-2  High-Stock-2  \
# 0       1855.75          568273      1.054570e+14        285.40        285.95
# 1       1842.82          945167      1.741770e+14        284.00        284.80
# 2       1893.91          679689      1.287270e+14        283.00        286.85
# 3       1889.21          509435      9.624280e+13        288.85        291.80
# 4       1873.32          961913      1.801970e+14        285.00        289.10
#
#    ...  VWAP-Stock-4  Volume-Stock-4  Turnover-Stock-4  Open-Stock-5  \
# ...

# %%
# define the data/predictors as the pre-set feature names  
dfp = df[["Open-Stock-4","High-Stock-4","Low-Stock-4","VWAP-Stock-4"]]
dft = df[["Close-Stock-4"]]

# %%
X = dfp
y = dft

# %%
import statsmodels.api as sm
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model
print(model.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:          Close-Stock-4   R-squared (uncentered):                   1.000
# Model:                            OLS   Adj. R-squared (uncentered):              1.000
# Method:                 Least Squares   F-statistic:                          1.882e+06
# Date:                Wed, 13 Jan 2021   Prob (F-statistic):                        0.00
# Time:                        14:12:06   Log-Likelihood:                         -986.33
# No. Observations:                 299   AIC:                                      1981.
# Df Residuals:                     295   BIC:                                      1995.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
predictions

# %%
df2 = pd.read_csv("new_test.csv")

# %%
dfp2 = df2[["Open-Stock-4","High-Stock-4","Low-Stock-4","VWAP-Stock-4"]]
#X2=dfp
dfp2
# Out:
#     Open-Stock-4  High-Stock-4  Low-Stock-4  VWAP-Stock-4
# 0        1008.50        1015.0       990.00       1003.31
# 1         970.00         979.7       950.00        961.50
# 2         940.05         975.0       933.40        953.24
# 3         915.00         967.6       910.45        938.80
# 4         963.95         971.2       957.70        964.75
# ..           ...           ...          ...           ...
# 92        690.00         741.0       683.60        708.17
# 93        728.40         734.4       714.30        724.00
# 94        721.00         734.7       719.05        729.09
# 95        727.10         734.0       721.35        726.56
# 96        720.70         720.8       694.35        703.75
#
# [97 rows x 4 columns]

# %%
predictions2 = model.predict(dfp2) # make the predictions by the model
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:          Close-Stock-4   R-squared (uncentered):                   1.000
# Model:                            OLS   Adj. R-squared (uncentered):              1.000
# Method:                 Least Squares   F-statistic:                          1.882e+06
# Date:                Wed, 13 Jan 2021   Prob (F-statistic):                        0.00
# Time:                        14:12:16   Log-Likelihood:                         -986.33
# No. Observations:                 299   AIC:                                      1981.
# Df Residuals:                     295   BIC:                                      1995.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
predictions2

# %%
predictions2.to_csv (r'C:\Users\MarkCichonski\Learn ML 2021 Grand AI Challenge\resultslr24.csv', index = False, header=True)

# %%
#https://stackoverflow.com/questions/47577168/how-can-i-increase-the-accuracy-of-my-linear-regression-modelmachine-learning
